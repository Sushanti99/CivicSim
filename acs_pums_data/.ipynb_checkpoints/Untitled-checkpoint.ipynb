# %%
! pip install ipumspy pandas
# Out:
# DEPRECATION: Loading egg at /opt/homebrew/anaconda3/lib/python3.11/site-packages/afinn-0.2.dev0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 24.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.6/29.6 MB 22.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 23.0.1
#     Uninstalling pyarrow-23.0.1:
#       Successfully uninstalled pyarrow-23.0.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
# ...

# %%
from ipumspy import readers

# Step 1: Read XML (this creates DDI object)
ddi = readers.read_ipums_ddi("usa_00001.xml")

# Step 2: Pass DDI to load data
df = readers.read_ipums_micro(ddi)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       4 ddi = readers.read_ipums_ddi("acs_pums_data/usa_00001.xml")
#       6 # Load data into dataframe
# ----> 7 df = readers.read_microdata("acs_pums_data/",ddi)
#       9 # Preview
#      10 print(df.head())
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/ipumspy/readers.py:285, in read_microdata(ddi, filename, encoding, subset, dtype, **kwargs)
#     261 """
#     262 Read in microdata as specified by the Codebook. Both .dat and .csv file types
#     263 are supported.
#    (...)
#     282     pandas data frame and pandas text file reader
#     283 """
#     284 # raise a warning if this is a hierarchical file
# --> 285 if ddi.file_description.structure == "hierarchical":
#     286     raise NotImplementedError(
# ...
